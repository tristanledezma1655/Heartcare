# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

url = "/content/drive/MyDrive/ProyectoFin/cardio_train.csv"
df = pd.read_csv(url, sep=";")

df.info()

df.duplicated().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB
# np.int64(0)

# %%
df_temp = df

# %%
df[df["cardio"] == 0]
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# 5          8  21914       1     151    67.0    120     80            2     2
# 6          9  22113       1     157    93.0    130     80            3     1
# 8         13  17668       1     158    71.0    110     70            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69987  99979  18852       1     151    49.0    120     80            1     1
# 69988  99981  21978       1     160    59.0    110     70            1     1
# 69991  99988  20609       1     159    72.0    130     90            2     2
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
temp_df[(temp_df["ap_hi"] > 250) & (temp_df["ap_hi"] < 40)]
# Out:
# Empty DataFrame
# Columns: [id, age, gender, height, weight, ap_hi, ap_lo, cholesterol, gluc, smoke, alco, active, cardio, imc]
# Index: []

# %%
dfl[dfl['weight'] <35]
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 3752    5306  15400       1     120    30.0    110     70            1     1
# 14722  21040  22663       1     143    34.0    100     70            1     1
# 16906  24167  17272       2     170    31.0    150     90            2     2
# 18559  26503  18140       1     160    30.0    120     80            1     1
# 22016  31439  15359       1     146    32.0    100     70            1     1
# 26806  38312  23284       1     157    23.0    110     80            1     1
# 29488  42156  20408       2     177    22.0    120     80            1     1
# 33511  47872  21081       1     153    34.0    110     70            3     3
# 33817  48318  21582       2     178    11.0    130     90            1     1
# 34276  48976  14664       2     128    28.0    120     80            1     1
# 35314  50443  19802       1     146    32.0    130     80            1     2
# ...

# %%
temp_df = dfl

# %%
temp_df = temp_df[(temp_df["weight"] <= 200) & (temp_df["weight"] >= 35)]
temp_df = temp_df[(temp_df["height"] <= 220) & (temp_df["height"] >= 120)]

# %%
temp_df.shape
# Out:
# (68650, 13)

# %%
temp_df[(temp_df["weight"] > 200) & (temp_df["weight"] < 35)]
# Out:
# Empty DataFrame
# Columns: [id, age, gender, height, weight, ap_hi, ap_lo, cholesterol, gluc, smoke, alco, active, cardio]
# Index: []

# %%
temp_df[(temp_df["height"] <= 200) & (temp_df["height"] >= 35)]
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
temp_df[(temp_df["height"] > 200) & (temp_df["height"] < 35)]
# Out:
# Empty DataFrame
# Columns: [id, age, gender, height, weight, ap_hi, ap_lo, cholesterol, gluc, smoke, alco, active, cardio]
# Index: []

# %%
dfl[dfl['weight'] >150]
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 389      552  16718       2     165   169.0    120     80            1     1
# 435      618  16765       1     186   200.0    130     70            1     1
# 2441    3438  19171       2     177   177.0    130     90            1     1
# 2458    3470  23646       2     159   165.0    130     70            1     1
# 3413    4825  14585       1     159   159.0    100     80            1     1
# 4743    6716  17218       2     176   180.0    140     90            1     1
# 6003    8526  14441       1     172   166.0    140     90            1     1
# 6153    8757  20990       1     122   161.0    120     80            1     1
# 7636   10899  15937       2     183   154.0    160    120            1     1
# 8171   11662  17646       2      97   170.0    160    100            1     1
# 8423   12020  14697       1     170   165.0    120     80            1     1
# ...

# %%
temp_df["imc"] = temp_df["weight"] / ((temp_df["height"] / 100) ** 2)

# %%
temp_df = temp_df[(temp_df["height"] <= 220) & (temp_df["height"] >= 130)]

# %%
temp_df[temp_df['imc']>55]
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 338      474  21078       1     157   142.0    120     80            1     1
# 389      552  16718       2     165   169.0    120     80            1     1
# 435      618  16765       1     186   200.0    130     70            1     1
# 1598    2258  16109       1     160   150.0    120     80            2     1
# 2340    3298  20988       1     160   150.0    160     75            1     1
# 2441    3438  19171       2     177   177.0    130     90            1     1
# 2458    3470  23646       2     159   165.0    130     70            1     1
# 3413    4825  14585       1     159   159.0    100     80            1     1
# 4732    6703  19868       1     164   149.0    120     80            2     2
# 4743    6716  17218       2     176   180.0    140     90            1     1
# 6003    8526  14441       1     172   166.0    140     90            1     1
# ...

# %%
temp_df[temp_df['imc']<12]
# Out:
# Empty DataFrame
# Columns: [id, age, gender, height, weight, ap_hi, ap_lo, cholesterol, gluc, smoke, alco, active, cardio, imc]
# Index: []

# %%
print(temp_df["imc"].shape)
# Out:
# (68650,)

# %%
temp_df[(temp_df["weight"] <= 200) & (temp_df["weight"] >= 35)]
